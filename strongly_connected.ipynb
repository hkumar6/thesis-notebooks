# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
g = nx.scale_free_graph(10)

# %%
nx.draw_circular(g)
plt.show()

# %%
while not nx.is_strongly_connected(g):
    e1 = np.random.randint(10)
    e2 = np.random.randint(10)
    print(e1, e2)
    g.add_edge(e1, e2, weight = 0.3)
# Out:
# 3 4
# 7 0
# 3 3
# 2 8
# 5 2
# 7 3
# 5 6
# 8 2
# 2 0
# 7 2
# 2 4
# 6 6
# 8 9
# 5 2
# 4 4
# 6 7
# 8 4
# 3 9
# 8 6
# 4 0
# 2 3
# 4 0
# 9 1
# 8 9
# 3 1
# 5 4
# 9 1
# 1 0
# 6 5

# %%
nx.draw_circular(g)
plt.show()

# %%
nx.is_strongly_connected(g)
# Out:
# True

# %%
print(nx.adjacency_matrix(g))
# Out:
#   (0, 1)	1.0
#   (0, 2)	0.3
#   (1, 0)	1.0
#   (1, 2)	1.3
#   (1, 3)	0.6
#   (1, 5)	0.8999999999999999
#   (1, 6)	0.3
#   (2, 0)	2.0
#   (2, 4)	0.3
#   (2, 5)	0.3
#   (3, 0)	1.0
#   (3, 1)	1.0
#   (3, 2)	0.3
#   (3, 4)	1.3
#   (3, 6)	0.3
#   (4, 1)	1.0
#   (4, 2)	0.3
#   (4, 6)	0.3
#   (4, 7)	0.3
#   (4, 9)	0.3
#   (5, 0)	2.0
#   (5, 1)	3.0
#   (5, 6)	1.3
#   (5, 7)	1.3
#   (6, 0)	0.3
#   (6, 6)	0.3
#   (6, 8)	0.3
#   (7, 2)	0.3
#   (7, 3)	0.3
#   (7, 5)	0.3
#   (7, 6)	0.6
#   (7, 7)	0.3
#   (7, 8)	0.3
#   (8, 0)	1.0
#   (8, 1)	0.3
#   (9, 0)	0.3
#   (9, 1)	1.0

# %%
plt.hist([d for n,d in g.degree()])
plt.show()

# %%
[d for n,d in g.degree()]
# Out:
# [11, 17, 10, 9, 8, 14, 11, 11, 4, 3]

# %%
g.in_edges(0)
# Out:
# InMultiEdgeDataView([(2, 0), (2, 0), (3, 0), (5, 0), (5, 0), (8, 0), (1, 0), (6, 0), (9, 0)])

# %%
g.out_edges(0)
# Out:
# OutMultiEdgeDataView([(0, 1), (0, 2)])

# %%
g.in_degree(0, weight='weight')
# Out:
# 7.6

# %%
g.out_degree(0, weight='weight')
# Out:
# 1.3
